# %%
import pandas as pd

df = pd.read_pickle('../data/all_messages_to_from_pickled')

# %%
df_no_email = df[df['channel'] != 'gmail']
df_no_email = df_no_email[df_no_email['channel'] != 'camera']
df_no_email = df_no_email[df_no_email['message'] != '        ']
b = [len(str(x).split()) for x in df_no_email['message']]
df_no_email['word_count'] = b

print df_no_email
# Out:
#          user_id  contact_id relationship       channel             sent_at  \
# 31            10          35           Ex  text_message 2011-02-18 06:50:35
# 32            10          35           Ex  text_message 2011-02-18 06:50:47
# 35            10          35           Ex  text_message 2011-02-22 02:22:54
# 37            10          35           Ex  text_message 2011-03-04 07:08:49
# 38            10          35           Ex  text_message 2011-03-04 08:17:59
# 39            10          35           Ex  text_message 2011-03-04 08:26:09
# 40            10          35           Ex  text_message 2011-03-04 09:44:44
# 41            10          35           Ex  text_message 2011-03-04 09:53:23
# 42            10          35           Ex  text_message 2011-03-13 01:16:55
# 43            10          35           Ex  text_message 2011-03-13 01:28:11
# 44            10          35           Ex  text_message 2011-03-13 01:36:15
# 45            10          35           Ex  text_message 2011-03-13 03:54:41
# 46            10          35           Ex  text_message 2011-03-13 04:13:11
# 47            10          35           Ex  text_message 2011-03-14 01:22:43
# 48            10          35           Ex  text_message 2011-03-14 02:14:12
# 49            10          35           Ex  text_message 2011-03-14 02:23:37
# 50            10          35           Ex  text_message 2011-03-14 02:26:04
# 51            10          35           Ex  text_message 2011-03-14 02:31:18
# 52            10          35           Ex  text_message 2011-03-14 02:32:16
# 53            10          35           Ex  text_message 2011-03-14 02:33:08
# 54            10          35           Ex  text_message 2011-03-14 02:46:43
# 55            10          35           Ex  text_message 2011-03-14 08:19:54
# 56            10          35           Ex  text_message 2011-03-14 08:22:01
# 57            10          35           Ex  text_message 2011-03-14 08:24:12
# 58            10          35           Ex  text_message 2011-03-14 08:24:32
# 59            10          35           Ex  text_message 2011-03-14 08:52:42
# 60            10          35           Ex  text_message 2011-03-14 08:52:58
# 61            10          35           Ex  text_message 2011-03-14 08:53:53
# 62            10          35           Ex  text_message 2011-03-14 14:57:27
# 63            10          35           Ex  text_message 2011-03-14 15:26:18
# ...          ...         ...          ...           ...                 ...
# 2859324    12334       33200       Family       hangout 2015-05-03 00:00:00
# 2859325    12334       33200       Family       hangout 2015-05-03 00:00:00
# 2859326    12334       33200       Family       hangout 2015-05-03 00:00:00
# 2859327    12334       33200       Family       hangout 2015-05-03 00:00:00
# 2859328    12334       33200       Family       hangout 2015-05-03 00:00:00
# 2859329    12334       33200       Family       hangout 2015-05-04 00:00:00
# 2859330    12334       33200       Family       hangout 2015-05-04 00:00:00
# 2859331    12334       33200       Family       hangout 2015-05-04 00:00:00
# 2859332    12334       33200       Family       hangout 2015-05-04 00:00:00
# 2859333    12334       33200       Family       hangout 2015-05-04 00:00:00
# 2859334    12334       33200       Family       hangout 2015-05-15 00:00:00
# 2859335    12334       33200       Family       hangout 2015-05-15 00:00:00
# 2859336    12334       33200       Family       hangout 2015-10-20 00:00:00
# 2859337    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859338    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859339    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859340    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859341    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859342    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859343    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859344    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859345    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859346    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859347    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859348    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859349    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859350    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859351    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859352    12334       33200       Family       hangout 2016-02-04 00:00:00
# 2859353    12334       33200       Family       hangout 2016-02-04 00:00:00
#
#                                                    message to_from  word_count
# 31                                       Ill be there in 3   False           5
# 32                                  hey I'm in the theater   False           5
# 35                                                      :)   False           1
# 37                                  Hey! How was the trip?   False           5
# 38         great! still feels like I'm recovering, though!   False           7
# 39       Awesome! Well, let's hang out when you return ...   False          10
# 40       definitely! don't spend toooo much time catalo...   False          16
# 41       Oh, there's something else altogether- I'll em...   False          24
# 42       Hey, I'm finally on break and would love to ha...   False          14
# 43       hey! i was just thinking about you. when's goo...   False          11
# 44                          Today is good, if you're free.   False           6
# 45       hmm, im actually downtown for a bit and then I...   False          15
# 46       Yeah tomorrow works. We'll touch base then. Ha...   False          10
# 47                               Hey! Still up for dinner?   False           5
# 48       hey aldo, yeah I'm totally up for it tonight. ...   False          33
# 49       Hmm can we meet after the call? Can't do Tuesday.   False          10
# 50       sure; good call. not sure how long it will be ...   False          15
# 51       You should take care of the call and we'll mee...   False          13
# 52                                                      :(   False           1
# 53             I'll let you know when I'm done just incase   False           9
# 54                               Ok, let's play it by ear.   False           6
# 55          ....just hung up. so sorry! late night snack??   False           8
# 56       Only if it's unhealthy. Do you like Mel's Burg...   False          12
# 57                                            sounds great   False           2
# 58                                       In half an hour?    False           4
# 59                        Just got this text. almost there   False           6
# 60                                  no rush if you're not!   False           5
# 61                      Ok, on my way too. See you soon ;)   False           9
# 62       Again, sorry for the weirdness. You caught me ...   False          15
# 63       it's ok! sorry to surprise. new terrain, ya kn...   False          31
# ...                                                    ...     ...         ...
# 2859324  new website is caca http://architecture.yale.edu/    True           5
# 2859325                              i _loved_ the old one    True           5
# 2859326                            can't even look at this   False           5
# 2859327                                          seriously    True           1
# 2859328                                               caca   False           1
# 2859329                        a ja odpowiedam na ten link    True           6
# 2859330      no to teraz podeśle kolejny link: polygon.com   False           7
# 2859331  Bardzo długi wielolinijkowy tekst w cely przet...   False          11
# 2859332                                             krótko    True           1
# 2859333  i nieco dłużej, bo stronka jest całkiem ok. Pr...    True          15
# 2859334                            idziemy zaraz na pociąg    True           4
# 2859335                                         15.05.2015    True           1
# 2859336             Dobra to coś jeszczę napiszę do Shryne   False           7
# 2859337    ale to może w takim razie napiszemy coś więcej?   False           9
# 2859338                                      www.google.pl    True           1
# 2859339       Trzeba wysłać parę dodatkowych wiadomości. 😀   False           6
# 2859340  Litwo! Ojczyzno moja! ty jesteś jak zdrowie.\n...    True         145
# 2859341                        TO testujemy hangouty dalej    True           4
# 2859342                                          polecat!!    True           1
# 2859343                                        oki dooki ☺   False           3
# 2859344  Można też spróbować napisać jakąś długą wiadom...    True          15
# 2859345                                 Klasyk, to lubie 😉   False           4
# 2859346  Mówią, że czarny kot przynosi\npecha.\n\nChcia...   False          98
# 2859347   Możesz wkleić linka do jakieś ciekawej stronki 😉    True           8
# 2859348                        co by tu jeszcze napisać...   False           5
# 2859349  no to jeszcze sprawdzimy czy po ponownym impor...    True          12
# 2859350  Pytanie czy od razu będzie można je zaimportow...   False          12
# 2859351               no nic, to próbujemy zaimportować to   False           6
# 2859352       Na raze bez attachmentów jedynie z ikonkami.    True           7
# 2859353  Ok, nie ma co testować wpisując same testy, wi...   False          17
#
# [2570613 rows x 8 columns]

# %%
from vader_sentiment_analysis import SentimentAnalyser
sentiment_analyser = SentimentAnalyser()
# Out:
# /home/dan/anaconda2/lib/python2.7/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
df_subset = df_no_email[df_no_email['contact_id'] == 16787]

# %%
df_subset
# Out:
#       user_id  contact_id relationship       channel             sent_at  \
# 5152       10       16787           Ex  text_message 2011-05-09 20:07:17
# 5153       10       16787           Ex  text_message 2011-05-09 20:07:40
# 5154       10       16787           Ex  text_message 2011-05-09 20:09:05
# 5155       10       16787           Ex  text_message 2011-05-09 20:09:20
# 5156       10       16787           Ex  text_message 2011-05-09 20:41:12
# 5157       10       16787           Ex  text_message 2011-05-09 20:41:26
# 5158       10       16787           Ex  text_message 2011-05-09 20:41:38
# 5159       10       16787           Ex  text_message 2011-05-09 20:42:52
# 5160       10       16787           Ex  text_message 2011-05-09 20:45:17
# 5161       10       16787           Ex  text_message 2011-05-09 20:45:25
# 5162       10       16787           Ex  text_message 2011-05-09 20:46:32
# 5163       10       16787           Ex  text_message 2011-05-09 21:41:21
# 5164       10       16787           Ex  text_message 2011-05-09 21:44:47
# 5165       10       16787           Ex  text_message 2011-05-09 21:45:44
# 5166       10       16787           Ex  text_message 2011-05-09 21:47:35
# 5167       10       16787           Ex  text_message 2011-05-09 21:47:55
# 5168       10       16787           Ex  text_message 2011-05-09 21:49:54
# 5169       10       16787           Ex  text_message 2011-05-09 21:51:25
# 5170       10       16787           Ex  text_message 2011-05-09 22:01:47
# 5171       10       16787           Ex  text_message 2011-05-09 22:02:55
# 5172       10       16787           Ex  text_message 2011-05-09 22:03:13
# 5173       10       16787           Ex  text_message 2011-05-09 22:04:52
# 5174       10       16787           Ex  text_message 2011-05-09 22:05:31
# 5175       10       16787           Ex  text_message 2011-05-09 22:07:25
# 5176       10       16787           Ex  text_message 2011-05-09 22:08:15
# 5177       10       16787           Ex  text_message 2011-05-09 22:10:01
# 5178       10       16787           Ex  text_message 2011-05-09 22:10:36
# 5179       10       16787           Ex  text_message 2011-05-09 22:12:31
# 5180       10       16787           Ex  text_message 2011-05-09 22:13:31
# 5181       10       16787           Ex  text_message 2011-05-09 22:15:43
# ...       ...         ...          ...           ...                 ...
# 5592       10       16787           Ex  text_message 2011-11-11 22:56:45
# 5593       10       16787           Ex  text_message 2011-11-11 23:01:32
# 5594       10       16787           Ex  text_message 2011-11-11 23:10:43
# 5595       10       16787           Ex  text_message 2011-11-11 23:15:16
# 5596       10       16787           Ex  text_message 2011-11-14 16:25:45
# 5597       10       16787           Ex  text_message 2011-11-20 13:35:37
# 5598       10       16787           Ex  text_message 2011-11-20 13:46:00
# 5599       10       16787           Ex  text_message 2011-11-20 14:29:02
# 5600       10       16787           Ex  text_message 2011-11-20 14:34:41
# 5601       10       16787           Ex  text_message 2011-12-03 14:03:00
# 5602       10       16787           Ex  text_message 2011-12-03 14:27:06
# 5603       10       16787           Ex  text_message 2011-12-03 14:29:25
# 5604       10       16787           Ex  text_message 2012-01-11 11:47:22
# 5605       10       16787           Ex  text_message 2012-01-11 17:17:24
# 5606       10       16787           Ex  text_message 2012-01-11 18:03:56
# 5607       10       16787           Ex  text_message 2012-01-19 20:23:09
# 5608       10       16787           Ex  text_message 2012-01-19 22:21:30
# 5609       10       16787           Ex  text_message 2012-01-19 22:27:32
# 5610       10       16787           Ex  text_message 2012-01-19 22:32:26
# 5611       10       16787           Ex  text_message 2012-01-19 22:35:23
# 5612       10       16787           Ex  text_message 2012-01-19 22:36:10
# 5613       10       16787           Ex  text_message 2012-02-01 21:16:48
# 5614       10       16787           Ex  text_message 2012-02-06 21:28:16
# 5615       10       16787           Ex  text_message 2012-02-07 18:12:11
# 5616       10       16787           Ex  text_message 2012-02-07 20:26:55
# 5617       10       16787           Ex  text_message 2012-05-20 18:07:47
# 5618       10       16787           Ex  text_message 2012-05-23 19:27:36
# 5619       10       16787           Ex  text_message 2012-05-24 00:00:47
# 5622       10       16787           Ex     instagram 2015-11-06 04:14:49
# 5623       10       16787           Ex     instagram 2015-11-06 18:57:37
#
#                                                 message to_from  word_count
# 5152                 Hey its marcelo! How's your night?    True           6
# 5153  Hey :) all is good. Out with friends. What are...   False          13
# 5154  Just got out of work, sooo tired and ready to ...    True          17
# 5155  Damn, that's rough! Well, rest well and let's ...   False          14
# 5156  Thanks, yes we can do that, I feel like I know...    True          16
# 5157  Fair enough. I don't mind just chatting for a ...   False          11
# 5158      Which could be a good thing I don't know haha    True          10
# 5159                                                 :)    True           1
# 5160  I read a your profile but was a little confuse...    True          26
# 5161  Yeah, mostly :) sorry I'm out with a friend, c...   False          16
# 5162                                 My bad, of course!    True           4
# 5163  Ok, free for now. So yeah, born and raised in ...   False          31
# 5164  I'm from queens! Haha I got to school for fash...    True          26
# 5165  That's cool, and I passed that urban outfitter...   False          25
# 5166  I've worked a couple shows not done many shoot...    True          30
# 5167  Program to get a foundation in fashion and sta...    True          12
# 5168  Very cool. Are you thinking of working in the ...   False          20
# 5169  Yeah definitely I'm thinking of doing an inter...    True          16
# 5170  That's so cool! I'm wrapping up my first year ...   False          37
# 5171       Haha, that's what we all want you to believe   False           9
# 5172  Busy man! Architecture school, you must be ver...    True           9
# 5173                   Haha, where doy ou do to school?    True           7
# 5174  Columbia, the grad school of arch. It's been a...   False          27
# 5175  Oh columbia! I live on the uws actually. I rea...    True          30
# 5176  I'll be around town til July, working on resea...   False          30
# 5177  That sounds so nice just up and leaving, are y...    True          21
# 5178  Haha, yes, should be back in august. And one's...   False          26
# 5179  You're very optimistic, I'm imagining that I w...    True          24
# 5180  Sleep is good, travel is good. Best thing: car...   False          23
# 5181  Definitely, either way I'm looking foward to h...    True          19
# ...                                                 ...     ...         ...
# 5592  I'm not being mean, mean would be ignoring you...    True          53
# 5593  Think back to when we started. I think we got ...   False          92
# 5594  Ok you're being dramatic now I have nothing el...    True          11
# 5595  This isn't an easy conversation to have. if yo...   False          35
# 5596  Hey, do you know about the Performa events goi...   False          26
# 5597  Last fall I met a guy. His eyes made my mind g...   False         574
# 5598  Im at work right now - I have no problem with ...    True          53
# 5599  You have been honest. I'd like to be friends t...   False          30
# 5600                                Thanks speak soon.     True           3
# 5601                                Hey, hows it going?   False           4
# 5602                              Hey just working you?    True           4
# 5603  Same, wrapping up my project for the final rev...   False          21
# 5604                           Hey Marcelo. How's life?   False           4
# 5605  Hey Aldo. Great just super busy with work and ...    True          14
# 5606         I'm good, just got back. Glad you're well.   False           8
# 5607  Hey, wanna catch up sometime? Maybe next weekend?   False           8
# 5608  Hey. Im pretty busy with fashion week prep sta...    True          28
# 5609  Go you! I've got a new guy too, so we're defin...   False          18
# 5610  Nice! Ya I'm chaperoning a party for natalies ...    True          26
# 5611                           Oh god. Yeah, talk soon.   False           5
# 5612                                         Okk night!    True           2
# 5613                                    Hey, hows life?   False           3
# 5614  The friend I was with when we met just moved b...   False          19
# 5615                                     Everything ok?   False           2
# 5616  I hope you're alive and well and are just igno...   False          32
# 5617  Out of all my friends, you run into the one wh...   False          21
# 5618     Let's get pizza tomorrow. It's been a while :)   False           9
# 5619  just want to see you again.  I do hope you dec...   False          16
# 5622                                             capton   False           1
# 5623                                                      False           0
#
# [470 rows x 8 columns]

# %%
updated_df = sentiment_analyser.run_vader(df_subset, 'message')
updated_df
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey its marcelo! How's your night?
#
# {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.8402}
# []
# Hey :) all is good. Out with friends. What are you up to?
#
# {'neg': 0.291, 'neu': 0.498, 'pos': 0.211, 'compound': -0.4753}
# []
# Just got out of work, sooo tired and ready to sleep haha. My feet are killing me!
#
# {'neg': 0.146, 'neu': 0.541, 'pos': 0.313, 'compound': 0.2714}
# []
# Damn, that's rough! Well, rest well and let's hang out sometime, if you want.
#
# {'neg': 0.0, 'neu': 0.576, 'pos': 0.424, 'compound': 0.7964}
# []
# Thanks, yes we can do that, I feel like I know very little about you though
#
# {'neg': 0.0, 'neu': 0.569, 'pos': 0.431, 'compound': 0.6486}
# []
# Fair enough. I don't mind just chatting for a while :)
#
# {'neg': 0.218, 'neu': 0.527, 'pos': 0.255, 'compound': 0.1078}
# []
# Which could be a good thing I don't know haha
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4588}
# []
# :)
#
# {'neg': 0.102, 'neu': 0.898, 'pos': 0.0, 'compound': -0.3634}
# []
# I read a your profile but was a little confused as to where you're from, when you say soviet union do you mean kazakstan?(Excuse my spelling)
#
# {'neg': 0.059, 'neu': 0.45, 'pos': 0.491, 'compound': 0.8625}
# []
# Yeah, mostly :) sorry I'm out with a friend, could we chat in like an hour?
#
# {'neg': 0.558, 'neu': 0.442, 'pos': 0.0, 'compound': -0.5848}
# []
# My bad, of course!
#
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.8102}
# []
# Ok, free for now. So yeah, born and raised in Kazakhstan until I was 12ish, then life became a bit of a clusterfuck. Where are you from? What do you do?
#
# {'neg': 0.07, 'neu': 0.655, 'pos': 0.274, 'compound': 0.7604}
# []
# I'm from queens! Haha I got to school for fashion design and work at urban outfitters in soho lol definitely not as interesting as your story
#
# {'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'compound': 0.8426}
# []
# That's cool, and I passed that urban outfitters an hour ago :) how are you enjoying fashion? Have you done any shows and shoots yet?
#
# {'neg': 0.039, 'neu': 0.793, 'pos': 0.168, 'compound': 0.6213}
# []
# I've worked a couple shows not done many shoots though which is what I'm more interested in for sure. I actually don't want to do design I'm just doing this
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Program to get a foundation in fashion and start working shortly after
#
# {'neg': 0.0, 'neu': 0.672, 'pos': 0.328, 'compound': 0.807}
# []
# Very cool. Are you thinking of working in the industry afterward? Its an interesting universe from what I've gathered :)
#
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.5994}
# []
# Yeah definitely I'm thinking of doing an internship at vogue this fall. What do you do?
#
# {'neg': 0.067, 'neu': 0.79, 'pos': 0.143, 'compound': 0.5069}
# []
# That's so cool! I'm wrapping up my first year of architecture school. Also doing research for the mayors office. Very, very boring stuff :) the exhibition for my studio is this Saturday so mostly working on that.
#
# {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.5106}
# []
# Haha, that's what we all want you to believe
#
# {'neg': 0.0, 'neu': 0.691, 'pos': 0.309, 'compound': 0.554}
# []
# Busy man! Architecture school, you must be very smart!
#
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.4588}
# []
# Haha, where doy ou do to school?
#
# {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.7476}
# []
# Columbia, the grad school of arch. It's been a rough year; we're all limping to the finish line :) when's summer break for you? Any grand plans?
#
# {'neg': 0.11, 'neu': 0.89, 'pos': 0.0, 'compound': -0.4753}
# []
# Oh columbia! I live on the uws actually. I really don't because its only 2 weeks long june 17 to...idk when. Just a sacrifice ill have to make though. You?
#
# {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'compound': 0.4588}
# []
# I'll be around town til July, working on research stuff. Then going to Ukraine and London for a bit. And you can do quite a lot with 2 weeks :)
#
# {'neg': 0.091, 'neu': 0.747, 'pos': 0.162, 'compound': 0.4036}
# []
# That sounds so nice just up and leaving, are you coming back? Yeahh I have no idea what to do though!
#
# {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.8689}
# []
# Haha, yes, should be back in august. And one's life can change so much during two weeks. Summer break always holds a surprise or two :)
#
# {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.7359}
# []
# You're very optimistic, I'm imagining that I will spend a lot of time sleeping in. It would be so nice to travel somewhere though.
#
# {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.9184}
# []
# Sleep is good, travel is good. Best thing: carefree time in the city. Do everything you've never done before. There's always so much!
#
# {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'compound': 0.4019}
# []
# Definitely, either way I'm looking foward to having a break, I've had have class mnday to friday since august
#
# {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.8905}
# []
# Whoa. Yeah, start with sleep then ;) I should actually go, about to meet up with someone. I'd love to chat more tomorrow :)
#
# {'neg': 0.0, 'neu': 0.378, 'pos': 0.622, 'compound': 0.5093}
# []
# Okk night! :)
#
# {'neg': 0.0, 'neu': 0.378, 'pos': 0.622, 'compound': 0.5093}
# []
# Okk night! :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, how's your day coming along?
#
# {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.7902}
# []
# Hey there, its going pretty well, I'm currently waiting in line at wendys for a bacon mushroom melt, very excited. How are you?
#
# {'neg': 0.0, 'neu': 0.65, 'pos': 0.35, 'compound': 0.9184}
# []
# Haha nice! I'm waiting for my margarita, the liquid kind... Might be working late tonight. I wanted to invite you to the exhibition opening on Saturday at 5. should be fun :)
#
# {'neg': 0.0, 'neu': 0.325, 'pos': 0.675, 'compound': 0.886}
# []
# Aw I'd love to :) can I bring a friend?
#
# {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.5983}
# []
# Definitely! I'll text you more details by then. Ttyl ;)
#
# {'neg': 0.055, 'neu': 0.81, 'pos': 0.135, 'compound': 0.68}
# []
# Hey Marcelo. I have a family emergency and am flying to Kazakhstan in a couple of hours. I'm afraid I'm going to miss our Saturday plans. I hope we can hang out when I'm back. My phone wont be working there, but you can reach me by email at aldongar@gmail.com or fb (aldoc). Take care!
#
# {'neg': 0.282, 'neu': 0.543, 'pos': 0.175, 'compound': 0.246}
# []
# Oh no! I'm so sorry to hear that ! I hope everything works out!
#
# {'neg': 0.0, 'neu': 0.167, 'pos': 0.833, 'compound': 0.6124}
# []
# Thanks. Be well.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey Marcelo! I just got back the other day and wanted to see if you're around. Aldo
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hi there! Im not in the city tonight but I'll be back tomorrow. How are you?
#
# {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.6124}
# []
# Doing well, thanks. How was your summer?
#
# {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.6239}
# []
# It's been good! A lot of change. I'm surprised to hear from you.
#
# {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'compound': 0.9457}
# []
# Yes, it's quite a miracle I survived that part of the world to come back and text you :) So has it all been good change?
#
# {'neg': 0.233, 'neu': 0.583, 'pos': 0.184, 'compound': -0.128}
# []
# I'm guessing I misunderstood something. How come you're surprised?
#
# {'neg': 0.046, 'neu': 0.737, 'pos': 0.217, 'compound': 0.7081}
# []
# Sorry! I'm in the middle of moving some stuff around. All changes for the good yes! I've just been working a lot figuring things out.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I don't know! We never met so I figured since I deleted my okcupid...
#
# {'neg': 0.164, 'neu': 0.61, 'pos': 0.226, 'compound': 0.0036}
# []
# Well, I did invite you to my  exhibition, so okcupid isn't really necessary :)
#
# {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.0772}
# []
# And we can always meet and chat. If you want to of course.
#
# {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.3182}
# []
# Sure why not. I'm kind of over the dating thing hence why I deleted it. But id be down to get a drink or whatever.
#
# {'neg': 0.209, 'neu': 0.553, 'pos': 0.237, 'compound': 0.1779}
# []
# It's a non-date date then. I'm free Wednesday/Thursday night. Unless you wanna go to a crazy freak party Tuesday night.
#
# {'neg': 0.589, 'neu': 0.111, 'pos': 0.3, 'compound': -0.3818}
# []
# Hm crazy freak party?
#
# {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'compound': 0.6369}
# []
# The wolf party at le souk. A look is encouraged, etc.
#
# {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612}
# []
# Like a costume?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Most ppl just put on a fun/crazy outfit and/or makeup. I'll wear smth goth.
#
# {'neg': 0.06, 'neu': 0.528, 'pos': 0.412, 'compound': 0.8398}
# []
# Sound like fun. Maybe I'll come by with a friend? It's not an exclusive thing is it?
#
# {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.4404}
# []
# Not sure if I can invite ppl at all. Hmm let me get back to you tomorrow.
#
# {'neg': 0.42, 'neu': 0.252, 'pos': 0.328, 'compound': -0.2732}
# []
# Ahh well no worries. Weds is fine.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'll check anyway. Ttyl
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Later
#
# {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.6872}
# []
# Hey, so my host definitely has space for the party, if you still wanna come
#
# {'neg': 0.0, 'neu': 0.342, 'pos': 0.658, 'compound': 0.7717}
# []
# Yeah is it cool if I bring a friend?
#
# {'neg': 0.0, 'neu': 0.613, 'pos': 0.387, 'compound': 0.6887}
# []
# Totally, my friend might join us too. It's gonna be ~ midnight
#
# {'neg': 0.0, 'neu': 0.25, 'pos': 0.75, 'compound': 0.4588}
# []
# Okk :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hii how are you
#
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# []
# Good, at a show. You?
#
# {'neg': 0.0, 'neu': 0.536, 'pos': 0.464, 'compound': 0.3802}
# []
# Cool! Just hanging out.
#
# {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.7003}
# []
# Nice :) still on for tonight?
#
# {'neg': 0.0, 'neu': 0.481, 'pos': 0.519, 'compound': 0.6597}
# []
# Yes definitely. Are you all gothed out?
#
# {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.6908}
# []
# Oh yes. Look forward to seeing what you'll be wearing :)
#
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.4588}
# []
# :) so what are the dets?
#
# {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.3612}
# []
# We're gonna meet up at like 11:45 at le souk. Cant remember the address. See you then?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Running late, let's make it midnight
#
# {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.296}
# []
# Ok I'm in west village now.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm on my way, let's meet on bleeker/Laguardia in 10-15?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Okk
#
# {'neg': 0.0, 'neu': 0.579, 'pos': 0.421, 'compound': 0.6249}
# []
# I'm right outside. You'll notice me I'm sure lol
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Of le souk walking now
#
# {'neg': 0.0, 'neu': 0.479, 'pos': 0.521, 'compound': 0.8692}
# []
# Thanks so much for everything! It was so nice meeting you :)
#
# {'neg': 0.0, 'neu': 0.581, 'pos': 0.419, 'compound': 0.855}
# []
# Glad you made it! Really nice meeting you too. Let's hang out again on thursday :)
#
# {'neg': 0.0, 'neu': 0.251, 'pos': 0.749, 'compound': 0.4574}
# []
# Definitely! Goodnight.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey! How's it going? What are you up to tonight?
#
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5106}
# []
# Heyy going to an opening later then I'm free. What about you?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Im at the BMW lab. Wanna grab a bite/drink later?
#
# {'neg': 0.144, 'neu': 0.637, 'pos': 0.219, 'compound': 0.2505}
# []
# Sure! Idk what time my friend wants to go to this gallery but what time would you want to meet? Slash where?
#
# {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.8126}
# []
# I'll be free after 7 and will be around Chelsea. I'm pretty flexible about time/place. Where do you wanna meet?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Really craving Japanese, but I'll eat anything. I can do Chelsea around 7.
#
# {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.2382}
# []
# Japanese sounds good, but I don't know of any places near Chelsea. Do you have one in mind?
#
# {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.4927}
# []
# Noo do you know any really good places elsewhere?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Sushiden on 49&madison, Hana sushi on 27 and 7, barmasa in Columbus sq are my favs. Any of those?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Columbus circle?
#
# {'neg': 0.0, 'neu': 0.313, 'pos': 0.688, 'compound': 0.296}
# []
# Yeah, circle.
#
# {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.4926}
# []
# That sounds good! How's 730?
#
# {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.7178}
# []
# That works. The place is super posh, so let me know if you'd prefer something more casual.
#
# {'neg': 0.0, 'neu': 0.916, 'pos': 0.084, 'compound': 0.296}
# []
# Ohh I should have thought of that it is Columbus circle hmm yeah I'd prefer something more chill what about the place on 27th and 7th?
#
# {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.5927}
# []
# That ones very basic but I know the owner and they make good sushi. Shall we do that instead?
#
# {'neg': 0.0, 'neu': 0.275, 'pos': 0.725, 'compound': 0.6468}
# []
# Sure! Yum so excited.
#
# {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'compound': 0.4374}
# []
# Cool! Meet you there at 7:30!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Okk!
#
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.4588}
# []
# Oops it's 22d and 7th :)
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4588}
# []
# :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm early!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm on my way, grab a table
#
# {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.4019}
# []
# Damn, I forgot to listen to bieber. Remind me next time
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Dammit! Do not listen to him with out me I repeat do not listen to justin beiber!!!!
#
# {'neg': 0.0, 'neu': 0.542, 'pos': 0.458, 'compound': 0.8752}
# []
# Don't worry, I'll maintain my bieber virginity until next time. And thanks for a lovely evening. G'night ;)
#
# {'neg': 0.0, 'neu': 0.509, 'pos': 0.491, 'compound': 0.6996}
# []
# :) thank you for the palm reading! Night
#
# {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.5106}
# []
# I think we should hang out again on Sunday. Are you free?
#
# {'neg': 0.0, 'neu': 0.222, 'pos': 0.778, 'compound': 0.8883}
# []
# I'd love to! Yes I'm free.
#
# {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.7096}
# []
# Weather should be good, wanna go to riverside park? I'll bring Prosecco, you bring bieber :)
#
# {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.6124}
# []
# Haha oh I will bring the bieber alright.
#
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.4588}
# []
# :) shall we say, 4pm at the 108 st entrance?
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6114}
# []
# Perfect!
#
# {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
# []
# See you then :)
#
# {'neg': 0.122, 'neu': 0.677, 'pos': 0.202, 'compound': 0.3321}
# []
# So the weather's pretty shit for the park. Wanna get a beer and a burger instead? There's a place I like called mel's on 111 and bway.
#
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.296}
# []
# Yeah that works. Same time?
#
# {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.0772}
# []
# Any time works for me. We can keep it at 4 if you want
#
# {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.6486}
# []
# I think the park is an option again :) shall we revert to the original plan?
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.3595}
# []
# Ok!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Agh your bed is so much comfier than this couch ;(
#
# {'neg': 0.164, 'neu': 0.565, 'pos': 0.271, 'compound': 0.2263}
# []
# Aww why are you on the couch :( good night and ttys ;)
#
# {'neg': 0.0, 'neu': 0.616, 'pos': 0.384, 'compound': 0.3595}
# []
# This is where I sleep! Gn
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey! How's your week going?
#
# {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.4939}
# []
# Heyy pretty decent how about you?
#
# {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.7096}
# []
# Good, recovering from last night. What are you up to this weekend? We still have bieber and a picnic on the to-do list :)
#
# {'neg': 0.084, 'neu': 0.719, 'pos': 0.197, 'compound': 0.4389}
# []
# Haha any recollection of last night this time? Idk there's supposed to be a hurricane!
#
# {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.8858}
# []
# Yes haha, just a headache this time! Hmm, well let's hang out anyway. When are you free?
#
# {'neg': 0.144, 'neu': 0.309, 'pos': 0.546, 'compound': 0.5994}
# []
# Haha just a hurricane nbd. Idk sat?
#
# {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'compound': 0.7717}
# []
# :) sat is perfect. We can decide on the details later..
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Whatre you up to right now
#
# {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.4939}
# []
# With a friend in the park. You?
#
# {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
# []
# Oh definitely. Stocked up on snacks already. What are your plans?
#
# {'neg': 0.0, 'neu': 0.745, 'pos': 0.255, 'compound': 0.34}
# []
# Hangin out at home. Excited for the storm?
#
# {'neg': 0.0, 'neu': 0.493, 'pos': 0.507, 'compound': 0.8504}
# []
# Haha kind of i think my friend isbahving a party? What're you doing tn?
#
# {'neg': 0.0, 'neu': 0.473, 'pos': 0.527, 'compound': 0.7783}
# []
# Just had drinks with a friend. Is that an invite? :)
#
# {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.2732}
# []
# Well we did have plans tomorrow. What are you doing tn though?
#
# {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.4939}
# []
# I'm done with my friend, so probably heading home. Shall we stick to tomorrow?
#
# {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.5574}
# []
# Yeah unless you want to hangout tn as well
#
# {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.4588}
# []
# I could be persuaded to come out :) what did you have in mind?
#
# {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'compound': 0.0772}
# []
# I just got home and crashed. You can come hang out if you want, I just don't think I can go out again today
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Wanna go for a walk in riverside park?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey I just woke up
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Really?
#
# {'neg': 0.093, 'neu': 0.549, 'pos': 0.359, 'compound': 0.743}
# []
# Haha, no way. I'm already camping in my room til Monday :) are you ready for tomorrow?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Yeahh i guess
#
# {'neg': 0.219, 'neu': 0.781, 'pos': 0.0, 'compound': -0.7089}
# []
# Aaand I'm tired of camping. Do you think it would be completely reckless for us to find a bar that's open and get a drink?
#
# {'neg': 0.0, 'neu': 0.567, 'pos': 0.433, 'compound': 0.7269}
# []
# Haha in kind of tied down to my friends tn
#
# {'neg': 0.0, 'neu': 0.316, 'pos': 0.684, 'compound': 0.7574}
# []
# Ok:) have fun & stay safe!
#
# {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.4926}
# []
# Thanks you too!
#
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.4588}
# []
# Hey :) wanna grab dinner tomorrow?
#
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4215}
# []
# Or, if the weather is nice, an evening picnic?
#
# {'neg': 0.0, 'neu': 0.122, 'pos': 0.878, 'compound': 0.8016}
# []
# Yes Love to!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# We'll decide tmr?
#
# {'neg': 0.0, 'neu': 0.145, 'pos': 0.855, 'compound': 0.7096}
# []
# Sounds good :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Picnic in CP at 6?
#
# {'neg': 0.398, 'neu': 0.602, 'pos': 0.0, 'compound': -0.3182}
# []
# Hey sorry have to cancel tn. Wednesday?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# My dad is coming to town on wednesday, so I'll be paralyzed til the weekend... Can you do tomorrow?
#
# {'neg': 0.0, 'neu': 0.901, 'pos': 0.099, 'compound': 0.296}
# []
# Possibly I'm just helping my sister move her stuff to a storage unit bc our basement flooded I'll let you know tmr?
#
# {'neg': 0.262, 'neu': 0.615, 'pos': 0.123, 'compound': -0.5267}
# []
# Oh, that sounds horrible :( keep me posted, and if anything we'll just hang out this weekend :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Okk!
#
# {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.5574}
# []
# Hey, hows it going? I'm free to meet tomorrow if you want to. Going to Boston this weekend...
#
# {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
# []
# Yes perhaps in the evening?
#
# {'neg': 0.0, 'neu': 0.459, 'pos': 0.541, 'compound': 0.7096}
# []
# Sounds good. Dinner perhaps? Or pinkberry :)
#
# {'neg': 0.0, 'neu': 0.7, 'pos': 0.3, 'compound': 0.4588}
# []
# Both it is :) let's plan for ~7?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Mm or both?
#
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.3818}
# []
# Later is fine. We can fine tune tomorrow
#
# {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.1531}
# []
# Ok but it mmay have to be later I will let you know
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.2263}
# []
# ;)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, how's it going?
#
# {'neg': 0.0, 'neu': 0.463, 'pos': 0.537, 'compound': 0.5399}
# []
# Hey!! Good at work
#
# {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.555}
# []
# You're being worked into the ground! Revival by pinkberry is in order! There's one near my place. And food too :)
#
# {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3595}
# []
# Ok! 8 o'clock?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Can we do 8:30?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hmm, 110/bway near the 1 train
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.3595}
# []
# Ok!
#
# {'neg': 0.344, 'neu': 0.656, 'pos': 0.0, 'compound': -0.2732}
# []
# Slash where are we meeting?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# On my way!
#
# {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.296}
# []
# Ok, I'm standing on the corner
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I just had a flashback! This is where I first texted you. In a queue to the bathroom in blockheads. Oy vey.
#
# {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.4215}
# []
# First time in what, may? Lol
#
# {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.6997}
# []
# Haha really? Like the first first time or when you got back from kazakstan
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Yaa
#
# {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.4588}
# []
# Haha mid text
#
# {'neg': 0.044, 'neu': 0.604, 'pos': 0.352, 'compound': 0.8805}
# []
# :) the super took sooo long, sorry. Come hang out at the new place when you have a free evening! Gluck w work today
#
# {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'compound': 0.2263}
# []
# Thnx ;)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey how's the move going?
#
# {'neg': 0.19, 'neu': 0.81, 'pos': 0.0, 'compound': -0.7316}
# []
# Hey! I've got 5 more hours  of hell left. Sleeping there tonight for the first time, the new mattress is amazingg. How are you?
#
# {'neg': 0.148, 'neu': 0.704, 'pos': 0.148, 'compound': 0.0}
# []
# Aw. I'm well just in the studio now. Kind of getting bored.
#
# {'neg': 0.088, 'neu': 0.795, 'pos': 0.117, 'compound': 0.1783}
# []
# Oh, slow day? I just survived a mad rush to move out on time, but it's done! What are you up to tonight?
#
# {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.4939}
# []
# An old friend is in town for the night so I'm just hanging out with him wbu
#
# {'neg': 0.0, 'neu': 0.495, 'pos': 0.505, 'compound': 0.6249}
# []
# Small housewarming thing. Enjoy the night ;)
#
# {'neg': 0.0, 'neu': 0.669, 'pos': 0.331, 'compound': 0.836}
# []
# Hey, wanna hang out tomorrow? My friend has a show at 5 if you're interested, then we can finally get some pinkberry :)
#
# {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.3802}
# []
# Heyy sure let me get back to you!
#
# {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.4574}
# []
# I'll be doing fittings starting at 2 so if I finish I'll definitely come! Can I buy a ticket when I get there?
#
# {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.5106}
# []
# The show is free and probably won't last long (5:30?). Text me when you're done either way
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Okk
#
# {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.4404}
# []
# Hey the show is at rockwood music hall stage 1 at 196 Allen st. Hope you make it
#
# {'neg': 0.115, 'neu': 0.729, 'pos': 0.156, 'compound': 0.2023}
# []
# There was a miscommunication- show's on the 14th :-/ lmk when you're done, we'll hang out :)
#
# {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3595}
# []
# Ohh ok!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# How's it going?
#
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4404}
# []
# :(
#
# {'neg': 0.524, 'neu': 0.476, 'pos': 0.0, 'compound': -0.296}
# []
# No umbrella dying
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Haven't seen you in a while- what are you up to the rest of the week?
#
# {'neg': 0.079, 'neu': 0.754, 'pos': 0.167, 'compound': 0.4019}
# []
# I know. I went straight to bed the other night when I said I would text you. Just been working a crazy amount today was pretty rough with the rain. How i
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# s the new place??
#
# {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.891}
# []
# Slowly filling in. Had classes today for the first time, then came home to chill and make dimpling soup. Enjoying freedom basically :) wanna get dinner tomorrow?
#
# {'neg': 0.287, 'neu': 0.713, 'pos': 0.0, 'compound': -0.5321}
# []
# hey I'm so sorry the past week has been really crazy for me
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I thought as much
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, if you wanna hang out/have time, there's that concert on wednesday at 6
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# So?
#
# {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.3665}
# []
# Sorry at fitting - Jeremy show is on Wednesday so I'm not sure. How are you?
#
# {'neg': 0.0, 'neu': 0.646, 'pos': 0.354, 'compound': 0.8297}
# []
# You work so late! I'm good, school blowing up in my face. I'm guessing you survived fashion week alright?
#
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.4588}
# []
# I guess it's still going. So out of touch right now :)
#
# {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
# []
# Yes still here working.
#
# {'neg': 0.0, 'neu': 0.131, 'pos': 0.869, 'compound': 0.9062}
# []
# Hope you're alive. Good luck tomorrow ;)
#
# {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.5106}
# []
# Hey, have you survived?
#
# {'neg': 0.0, 'neu': 0.495, 'pos': 0.505, 'compound': 0.6249}
# []
# Glad you are. Did all go well?
#
# {'neg': 0.0, 'neu': 0.321, 'pos': 0.679, 'compound': 0.8934}
# []
# Hey yes I'm alive and thank you for wishing me luck
#
# {'neg': 0.0, 'neu': 0.164, 'pos': 0.836, 'compound': 0.624}
# []
# Yes very well
#
# {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
# []
# What are you up to tonight? 4 of my classmates are having a little birthday houseparty if you're interested.
#
# {'neg': 0.555, 'neu': 0.445, 'pos': 0.0, 'compound': -0.7572}
# []
# I'm not sure, I'm pretty tired, still at work
#
# {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.8689}
# []
# Should be a mellow party. And we're going out for drinks at 6-9. Dinner somewhere too. Hope you'll decide to join :)
#
# {'neg': 0.231, 'neu': 0.523, 'pos': 0.246, 'compound': 0.0516}
# []
# That's really sweet. I don't think I can, I'm totally broke
#
# {'neg': 0.129, 'neu': 0.714, 'pos': 0.157, 'compound': 0.1531}
# []
# Not a problem- all the drinks are free tonight, and I can get your dinner, if you don't mind.
#
# {'neg': 0.0, 'neu': 0.378, 'pos': 0.622, 'compound': 0.5095}
# []
# That's very sweet
#
# {'neg': 0.11, 'neu': 0.63, 'pos': 0.26, 'compound': 0.4404}
# []
# Idk if going to be any fun to be around
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm *
#
# {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.5859}
# []
# It'll be fine :) come up when you're done with work
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey I just got home and showered don't know if I have it in me tn
#
# {'neg': 0.403, 'neu': 0.139, 'pos': 0.458, 'compound': 0.1027}
# []
# :( it's fun
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# 110&bway
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Where is it
#
# {'neg': 0.252, 'neu': 0.479, 'pos': 0.269, 'compound': 0.0444}
# []
# Lol would it come up? I don't care.
#
# {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.296}
# []
# Ok I'm leaving now
#
# {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'compound': 0.6369}
# []
# Btw are we telling ppl we met through ok Cupid haha
#
# {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.296}
# []
# Ok what's the address
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Meet me at 110 bway southeast corner
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}
# []
# Ok
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm here now
#
# {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.8625}
# []
# Just got back. Enjoy your day of r&r :)
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.7096}
# []
# :) thanks
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, how's it going?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey stickig my feet in bleach wbu?
#
# {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.4215}
# []
# Lol why? I just came home from a 14 hour day. Gonna veg out.
#
# {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.4939}
# []
# My friend spray tanned me a few weeks ago and my toenails got stained and turned orange. Apparently this is a quick remedy. I've had zero results.
#
# {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compound': 0.5321}
# []
# Haha! My sister used a hot towel to clean her palms. Amateur, but it worked!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Do you wanna hang out tomorrow/wed night? We can make dinner at my place.
#
# {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.3182}
# []
# Sure tonight?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm on a site visit, should be home at 7-7:15. When do you wanna come over?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Let's say 8?
#
# {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}
# []
# Sounds good. Come to 616 w 113 st
#
# {'neg': 0.0, 'neu': 0.332, 'pos': 0.668, 'compound': 0.9013}
# []
# Loving the sweater. Hope you didn't get into trouble :)
#
# {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.6808}
# []
# Aw yes all good over here
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm walking past ur face dining spot thalia
#
# {'neg': 0.13, 'neu': 0.703, 'pos': 0.167, 'compound': 0.1759}
# []
# Nice! I just got out of a gruesome work session with my team. How was the shoot?
#
# {'neg': 0.0, 'neu': 0.383, 'pos': 0.617, 'compound': 0.9441}
# []
# Really good kind of amazing excited for December issue to publish. Lester is truly amazing
#
# {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.936}
# []
# :) i guess this will be my first purchase of Elle magazine- to see your name in shining lights. You mentioned you've plans on Friday, but just in case, my friend is having a party in Brooklyn that should be fun.
#
# {'neg': 0.0, 'neu': 0.547, 'pos': 0.453, 'compound': 0.3578}
# []
# Okk we'll see!! ;)
#
# {'neg': 0.219, 'neu': 0.504, 'pos': 0.277, 'compound': 0.1531}
# []
# Cool. Tomorrow night is also pretty open if you wanna hang out. Ok I'm collapsing into my bed. Death.
#
# {'neg': 0.0, 'neu': 0.708, 'pos': 0.292, 'compound': 0.6983}
# []
# Eating the other slice of the pumpkin pie. I see why you like them so much :)
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4588}
# []
# :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, how's your weekend?
#
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# []
# Heyy good how's yours?
#
# {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.7269}
# []
# My friend that's an architecture student was asking me if you knew of any good firms in London she could intern for
#
# {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.7717}
# []
# Good, recovering from yesterday in the basement of the Morgan library. Not sure about London firms, she could try zaha hadid if her skin is thick. Peter cook is intriguing too. And countless corporate firms like som.
#
# {'neg': 0.0, 'neu': 0.696, 'pos': 0.304, 'compound': 0.8622}
# []
# Yeah I mean she Has been researching them but he doesent know which ones are truly reputable and just wanted some names to look into. Thanks!
#
# {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.7506}
# []
# She should go to Copenhagen, vienna, Basel or Paris. Much better options there, professionally. But London is the superior city. What are you up to this week?
#
# {'neg': 0.323, 'neu': 0.677, 'pos': 0.0, 'compound': -0.5826}
# []
# Idk really I don't think we have any projects right now which sucks!!!
#
# {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.5562}
# []
# But think of how much free time you have! Wanna go see some bands on Tuesday at rockwood?
#
# {'neg': 0.452, 'neu': 0.354, 'pos': 0.194, 'compound': -0.6562}
# []
# Ah I hate free time!!!!!!!!!! What's rockwood? I'm broke ;(
#
# {'neg': 0.0, 'neu': 0.799, 'pos': 0.201, 'compound': 0.7783}
# []
# Also you know a lot about being abroad can I give my friend your email so she can ask you about European firms. She's one of my dearest and I would reall
#
# {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compound': 0.4019}
# []
# y appreciate it.
#
# {'neg': 0.152, 'neu': 0.49, 'pos': 0.359, 'compound': 0.8234}
# []
# Rockwood is a small bar/stage with free shows, so no worries! And I'd be happy to help your friend, she can email me at aldongar@gmail.com
#
# {'neg': 0.0, 'neu': 0.38, 'pos': 0.62, 'compound': 0.5994}
# []
# Ooh okay :) let's go
#
# {'neg': 0.0, 'neu': 0.711, 'pos': 0.289, 'compound': 0.6478}
# []
# I just got the most delicious looking blueberry apple crumble pie at a farmers market. Want a slice?
#
# {'neg': 0.165, 'neu': 0.471, 'pos': 0.364, 'compound': 0.3987}
# []
# Mm idk if I like blueberry pie!!
#
# {'neg': 0.0, 'neu': 0.75, 'pos': 0.25, 'compound': 0.4588}
# []
# You don't get a say anymore, I just ate it all :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Still wanna go to rockwood tomorrow? Shows start at 6, so we can meet anytime then or after (new band every hour). When do you get off work?
#
# {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.296}
# []
# Yeah I think so
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, wanna meet up for the 7pm show?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Mhm! I'll let u know when I get out of work
#
# {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.6808}
# []
# I need like an hour notice to get there, I'll be working til then. Cheers
#
# {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.296}
# []
# Ok I'm on my way to ikea so I probably won't be back until 7 ish so let's meet at 8?
#
# {'neg': 0.0, 'neu': 0.435, 'pos': 0.565, 'compound': 0.6369}
# []
# Ok, see you there at 8 :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm here, will meet you outside.
#
# {'neg': 0.117, 'neu': 0.883, 'pos': 0.0, 'compound': -0.4026}
# []
# Hey I literally just got back tithe city from ikea and I have to meet my roomate right now I'm not sure if I'm going to make it tonight I'm so sorry
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Make it up toyou asap xo
#
# {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.4215}
# []
# How nice of you.
#
# {'neg': 0.218, 'neu': 0.436, 'pos': 0.347, 'compound': 0.7041}
# []
# Sorry my friend lost her job I have to be with her !! Sorry!!!! Hope didn't ruin your night :(
#
# {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.8542}
# []
# It would have been nice not to have wasted 3 hours, but you do what you need to do. Hope she's ok.
#
# {'neg': 0.132, 'neu': 0.646, 'pos': 0.222, 'compound': 0.7362}
# []
# I'm sorry that I cant make it I domt know why you wasted 3 hours as I said we would meet at 8 but I'm very sorry. And I hope so too thank you.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Trains and waiting take time. Whatever, I'll ttyl.
#
# {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'compound': 0.9517}
# []
# Hope your friend is doing alright. Have a good night and let's hang out before the weekend- I'll be super busy then. Cheers
#
# {'neg': 0.0, 'neu': 0.428, 'pos': 0.572, 'compound': 0.854}
# []
# Thanks you're so sweet. She's good now. Have a goodnight. Let's.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, how's it going?
#
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.296}
# []
# Egh ok how are you
#
# {'neg': 0.27, 'neu': 0.73, 'pos': 0.0, 'compound': -0.5859}
# []
# Shaking and crying in my bed after an 8 hour review. What are you up to?
#
# {'neg': 0.265, 'neu': 0.735, 'pos': 0.0, 'compound': -0.7346}
# []
# My cat got into the fly trap and she's got sticky stuff all over and its stuck in her fur I'm really upset
#
# {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'compound': -0.4404}
# []
# :( try showering her with soap. If not, shaving is the only option. Or turpentine...
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Ughghhhgghhhh
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Im opening a bottle of Prosecco. Wanna cone over for a drink?
#
# {'neg': 0.752, 'neu': 0.248, 'pos': 0.0, 'compound': -0.7245}
# []
# I'm really upset :(
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Vodka?
#
# {'neg': 0.434, 'neu': 0.424, 'pos': 0.141, 'compound': -0.6387}
# []
# Haha no I don't want to get drunk I'm just in a really sad mood now
#
# {'neg': 0.071, 'neu': 0.489, 'pos': 0.44, 'compound': 0.7783}
# []
# I'm sorry to hear that. She'll be ok, just needs a good cleaning :)
#
# {'neg': 0.215, 'neu': 0.657, 'pos': 0.129, 'compound': -0.3488}
# []
# She's licking herself I think she's going to get very sick I can't stop her
#
# {'neg': 0.0, 'neu': 0.77, 'pos': 0.23, 'compound': 0.4574}
# []
# Google will answer how to clean her. Get on it asap!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I already did it's not working she runs away from me
#
# {'neg': 0.107, 'neu': 0.757, 'pos': 0.136, 'compound': 0.1506}
# []
# Cats don't like to be washed. You need to overpower her. And maybe get someone to help.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Everyones at dinner for rosh hashana
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Ughhhhhhhh I give up I'm just going to sleep
#
# {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.3382}
# []
# Early night! Rest well and let's hang out tomorrow night.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, how's your cat?
#
# {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.4404}
# []
# Hey she's good she licked it off mostly
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# ...and lived to tell the tale!
#
# {'neg': 0.0, 'neu': 0.703, 'pos': 0.297, 'compound': 0.6705}
# []
# Would you like to come over tonight? I got a pumpkin pie at the farmers market :)
#
# {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.3182}
# []
# Aw sure
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Wanna come over at 9? I'll be done by then.
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}
# []
# Ok
#
# {'neg': 0.0, 'neu': 0.313, 'pos': 0.688, 'compound': 0.296}
# []
# Everything ok?
#
# {'neg': 0.33, 'neu': 0.67, 'pos': 0.0, 'compound': -0.3544}
# []
# Sorry fell asleep!!! Heading over now!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# What's your address
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# 616 113 3r
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Omg should I bring milk for the pie?
#
# {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'compound': 0.0772}
# []
# If you want to
#
# {'neg': 0.413, 'neu': 0.587, 'pos': 0.0, 'compound': -0.2057}
# []
# I don't want a casual thing. not anymore.
#
# {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.8955}
# []
# I've given it some thought and I like what we have. If you want to continue meeting, I'm all for it. Also, if you're free tomorrow night, there's a really cool event in greenpoint where my friends have an installation (it's a light festival). Wanna come?
#
# {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.5848}
# []
# Thanks for the invite. I'll let ya know!
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4588}
# []
# :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# I'm thinking of heading over at 9. Wanna go?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Wait so what is this again?
#
# {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.9186}
# []
# It's called Nuit Blance, an art festival where the creative and design elite transforms a neighborhood with light installations. Should be amazing and two friends of mine made one
#
# {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.3182}
# []
# Oh cool
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Okk
#
# {'neg': 0.128, 'neu': 0.872, 'pos': 0.0, 'compound': -0.296}
# []
# Wanna meet up and go over together? I can stop by 87 st if you'll be there.
#
# {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# []
# Yaa sounds good
#
# {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.4588}
# []
# Meet you on bway/87 @9 :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Okk
#
# {'neg': 0.109, 'neu': 0.68, 'pos': 0.211, 'compound': 0.3612}
# []
# I'm stopping at my friends down the way wanna meet me there
#
# {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'compound': 0.3182}
# []
#  Sure, where's that
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# 77 and west end
#
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.296}
# []
# Ok, be there in ten
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Okk
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# At the corner
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, how are you?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey!!! How are you?
#
# {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.2732}
# []
# I'm well
#
# {'neg': 0.0, 'neu': 0.628, 'pos': 0.372, 'compound': 0.8767}
# []
# Recovering from a wisdom tooth extraction. Should be a fun few days :) are you back in town? How was the trip?
#
# {'neg': 0.168, 'neu': 0.718, 'pos': 0.114, 'compound': -0.3129}
# []
# Omg!!! You poor thing. Yes Got a lot of shoots going on so I'm just back to being busy again
#
# {'neg': 0.0, 'neu': 0.394, 'pos': 0.606, 'compound': 0.9423}
# []
# Good to hear :) good luck with stuff and let's hang out soon. Well, after I recover :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Aww how much longer do you think?
#
# {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.5562}
# []
# I grew a chipmunk cheek in the last hour and am in a bit of pain. Might be a few days? At least I have vicodin to trip on!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Yayy getting high
#
# {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.2263}
# []
# Oh, and Angela emailed me. I'm gonna reply tomorrow. Gnight ;)
#
# {'neg': 0.0, 'neu': 0.415, 'pos': 0.585, 'compound': 0.8704}
# []
# Aw thanks so much! Have a good night enjoy those clouds!
#
# {'neg': 0.0, 'neu': 0.4, 'pos': 0.6, 'compound': 0.4588}
# []
# Haha will do
#
# {'neg': 0.0, 'neu': 0.295, 'pos': 0.705, 'compound': 0.7339}
# []
# Hope you're feeling ok !! Xo
#
# {'neg': 0.0, 'neu': 0.237, 'pos': 0.763, 'compound': 0.9442}
# []
# I'm a chipmunk, but otherwise feeling fine. Thanks for caring :)
#
# {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'compound': 0.2942}
# []
# Take lots of pics of your new bone structure while you can! ;)
#
# {'neg': 0.334, 'neu': 0.666, 'pos': 0.0, 'compound': -0.3632}
# []
# Nah, the world will never see me like this.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, how's life? Last week of work?
#
# {'neg': 0.205, 'neu': 0.541, 'pos': 0.254, 'compound': 0.2878}
# []
# Hey everything is good I'm pretty tired from working and not at all excited to start school
#
# {'neg': 0.0, 'neu': 0.579, 'pos': 0.421, 'compound': 0.6249}
# []
# Aww, well you have another week of "rest" :)
#
# {'neg': 0.088, 'neu': 0.717, 'pos': 0.195, 'compound': 0.4479}
# []
# Haha yaa how about you howa ur mouth?? Did you havebtoo miss a lot of class?
#
# {'neg': 0.144, 'neu': 0.691, 'pos': 0.165, 'compound': 0.001}
# []
# Mouth is almost fully healed, couldn't miss school- midterm week. Might stay up working all night. This week is promising to be tough... We should hang out, but I have no idea when I'll be free next :(
#
# {'neg': 0.16, 'neu': 0.67, 'pos': 0.17, 'compound': 0.0516}
# []
# I just watched a Justin bieber video. Sad it wasn't with you, to be honest. How's work?
#
# {'neg': 0.0, 'neu': 0.527, 'pos': 0.473, 'compound': 0.555}
# []
# Haha what did you think!!
#
# {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}
# []
# Baby is the best thing everrrrr
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# What did I tell ya
#
# {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.5093}
# []
# Haha. So what's new? I feel I haven't seen you in forever!
#
# {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4753}
# []
# Just been working a lot! 70 hours last week not as much this week thankfully. How about you?
#
# {'neg': 0.0, 'neu': 0.771, 'pos': 0.229, 'compound': 0.8908}
# []
# Wow... Intense. I've been about as busy, had my review today (went super well!). Now my parents are back in town and my friend from college is staying with me, so I'll be hella hectic til sund-ay/Monday. Hope we can hang out then?
#
# {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.3987}
# []
# Aw! Well I start school Monday so we'll see!
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4588}
# []
# :)
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hows the last day going?
#
# {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.4404}
# []
# It was good. Just laying in bed with Natalie she just had her eye surgery
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Lasik?
#
# {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'compound': -0.296}
# []
# No it's a different procedure she won't be able to see for a few days
#
# {'neg': 0.0, 'neu': 0.3, 'pos': 0.7, 'compound': 0.717}
# []
# ! That's intense! I hope she's doing ok.
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404}
# []
# Thanks
#
# {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.6943}
# []
# I'm guessing you're not going out tonight? There's a little post midterm party up here tonight. If you can and want to, come :)
#
# {'neg': 0.214, 'neu': 0.786, 'pos': 0.0, 'compound': -0.6544}
# []
# Hey, hows it going? It's a travesty we haven't hung out in so long! Wanna come over tomorrow?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Why the silence?
#
# {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.6884}
# []
# It's complicated Aldo, I hope your feelings are not hurt
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Try me
#
# {'neg': 0.214, 'neu': 0.786, 'pos': 0.0, 'compound': -0.5205}
# []
# It's not something I want to talk about over text but I'm too embarrassed to face it in person
#
# {'neg': 0.11, 'neu': 0.628, 'pos': 0.262, 'compound': 0.4386}
# []
# Well, I think it's better to talk about whatever it is. It's not like we're strangers.
#
# {'neg': 0.028, 'neu': 0.914, 'pos': 0.058, 'compound': 0.4549}
# []
# ...
#
# {'neg': 0.155, 'neu': 0.688, 'pos': 0.157, 'compound': 0.476}
# []
# Im at work right now - I have no problem with being friends. It makes me sad to think about how this all may have hurt you but you have to listen very carefully when I speak on what I do and do not want - Ive always been very honest with you.
#
# {'neg': 0.0, 'neu': 0.587, 'pos': 0.413, 'compound': 0.9423}
# []
# You have been honest. I'd like to be friends too. Let's hang out sometime this week. Maybe we can see some bands at rockwood. Hope work is going well :)
#
# {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# []
# Thanks speak soon.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, hows it going?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey just working you?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Same, wrapping up my project for the final review on Tuesday. How's work been going? Are you done with school yet?
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey Marcelo. How's life?
#
# {'neg': 0.0, 'neu': 0.498, 'pos': 0.502, 'compound': 0.9022}
# []
# Hey Aldo. Great just super busy with work and friends etc. How are you?
#
# {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.7906}
# []
# I'm good, just got back. Glad you're well.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, wanna catch up sometime? Maybe next weekend?
#
# {'neg': 0.0, 'neu': 0.74, 'pos': 0.26, 'compound': 0.8313}
# []
# Hey. Im pretty busy with fashion week prep starting. I'm also seeing someone...but if you're ok with still being just friends we can def get together some time!
#
# {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.7484}
# []
# Go you! I've got a new guy too, so we're definitely just friends. A bite next Sunday afternoon?
#
# {'neg': 0.0, 'neu': 0.845, 'pos': 0.155, 'compound': 0.4664}
# []
# Nice! Ya I'm chaperoning a party for natalies little brother on Saturday night so i might be sleeping all day sunday but let's be in touch.
#
# {'neg': 0.0, 'neu': 0.411, 'pos': 0.589, 'compound': 0.5106}
# []
# Oh god. Yeah, talk soon.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Okk night!
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# Hey, hows life?
#
# {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.4939}
# []
# The friend I was with when we met just moved back from Paris/says hi. How's fashion week prep going?
#
# {'neg': 0.0, 'neu': 0.313, 'pos': 0.688, 'compound': 0.296}
# []
# Everything ok?
#
# {'neg': 0.064, 'neu': 0.495, 'pos': 0.441, 'compound': 0.9325}
# []
# I hope you're alive and well and are just ignoring me. I did think we could be good friends and I wasn't looking to get back together. Take care of yourself ;)
#
# {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.7964}
# []
# Out of all my friends, you run into the one who never remembers you. It's good to hear you're well. aldo
#
# {'neg': 0.0, 'neu': 0.7, 'pos': 0.3, 'compound': 0.4588}
# []
# Let's get pizza tomorrow. It's been a while :)
#
# {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4939}
# []
# just want to see you again.  I do hope you decide to get back in touch.
#
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# []
# capton
#
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# []
#       user_id  contact_id relationship       channel             sent_at  \
# 5152       10       16787           Ex  text_message 2011-05-09 20:07:17
# 5153       10       16787           Ex  text_message 2011-05-09 20:07:40
# 5154       10       16787           Ex  text_message 2011-05-09 20:09:05
# 5155       10       16787           Ex  text_message 2011-05-09 20:09:20
# 5156       10       16787           Ex  text_message 2011-05-09 20:41:12
# 5157       10       16787           Ex  text_message 2011-05-09 20:41:26
# 5158       10       16787           Ex  text_message 2011-05-09 20:41:38
# 5159       10       16787           Ex  text_message 2011-05-09 20:42:52
# 5160       10       16787           Ex  text_message 2011-05-09 20:45:17
# 5161       10       16787           Ex  text_message 2011-05-09 20:45:25
# 5162       10       16787           Ex  text_message 2011-05-09 20:46:32
# 5163       10       16787           Ex  text_message 2011-05-09 21:41:21
# 5164       10       16787           Ex  text_message 2011-05-09 21:44:47
# 5165       10       16787           Ex  text_message 2011-05-09 21:45:44
# 5166       10       16787           Ex  text_message 2011-05-09 21:47:35
# 5167       10       16787           Ex  text_message 2011-05-09 21:47:55
# 5168       10       16787           Ex  text_message 2011-05-09 21:49:54
# 5169       10       16787           Ex  text_message 2011-05-09 21:51:25
# 5170       10       16787           Ex  text_message 2011-05-09 22:01:47
# 5171       10       16787           Ex  text_message 2011-05-09 22:02:55
# 5172       10       16787           Ex  text_message 2011-05-09 22:03:13
# 5173       10       16787           Ex  text_message 2011-05-09 22:04:52
# 5174       10       16787           Ex  text_message 2011-05-09 22:05:31
# 5175       10       16787           Ex  text_message 2011-05-09 22:07:25
# 5176       10       16787           Ex  text_message 2011-05-09 22:08:15
# 5177       10       16787           Ex  text_message 2011-05-09 22:10:01
# 5178       10       16787           Ex  text_message 2011-05-09 22:10:36
# 5179       10       16787           Ex  text_message 2011-05-09 22:12:31
# 5180       10       16787           Ex  text_message 2011-05-09 22:13:31
# 5181       10       16787           Ex  text_message 2011-05-09 22:15:43
# ...       ...         ...          ...           ...                 ...
# 5592       10       16787           Ex  text_message 2011-11-11 22:56:45
# 5593       10       16787           Ex  text_message 2011-11-11 23:01:32
# 5594       10       16787           Ex  text_message 2011-11-11 23:10:43
# 5595       10       16787           Ex  text_message 2011-11-11 23:15:16
# 5596       10       16787           Ex  text_message 2011-11-14 16:25:45
# 5597       10       16787           Ex  text_message 2011-11-20 13:35:37
# 5598       10       16787           Ex  text_message 2011-11-20 13:46:00
# 5599       10       16787           Ex  text_message 2011-11-20 14:29:02
# 5600       10       16787           Ex  text_message 2011-11-20 14:34:41
# 5601       10       16787           Ex  text_message 2011-12-03 14:03:00
# 5602       10       16787           Ex  text_message 2011-12-03 14:27:06
# 5603       10       16787           Ex  text_message 2011-12-03 14:29:25
# 5604       10       16787           Ex  text_message 2012-01-11 11:47:22
# 5605       10       16787           Ex  text_message 2012-01-11 17:17:24
# 5606       10       16787           Ex  text_message 2012-01-11 18:03:56
# 5607       10       16787           Ex  text_message 2012-01-19 20:23:09
# 5608       10       16787           Ex  text_message 2012-01-19 22:21:30
# 5609       10       16787           Ex  text_message 2012-01-19 22:27:32
# 5610       10       16787           Ex  text_message 2012-01-19 22:32:26
# 5611       10       16787           Ex  text_message 2012-01-19 22:35:23
# 5612       10       16787           Ex  text_message 2012-01-19 22:36:10
# 5613       10       16787           Ex  text_message 2012-02-01 21:16:48
# 5614       10       16787           Ex  text_message 2012-02-06 21:28:16
# 5615       10       16787           Ex  text_message 2012-02-07 18:12:11
# 5616       10       16787           Ex  text_message 2012-02-07 20:26:55
# 5617       10       16787           Ex  text_message 2012-05-20 18:07:47
# 5618       10       16787           Ex  text_message 2012-05-23 19:27:36
# 5619       10       16787           Ex  text_message 2012-05-24 00:00:47
# 5622       10       16787           Ex     instagram 2015-11-06 04:14:49
# 5623       10       16787           Ex     instagram 2015-11-06 18:57:37
#
#                                                 message to_from  word_count  \
# 5152                 Hey its marcelo! How's your night?    True           6
# 5153  Hey :) all is good. Out with friends. What are...   False          13
# 5154  Just got out of work, sooo tired and ready to ...    True          17
# 5155  Damn, that's rough! Well, rest well and let's ...   False          14
# 5156  Thanks, yes we can do that, I feel like I know...    True          16
# 5157  Fair enough. I don't mind just chatting for a ...   False          11
# 5158      Which could be a good thing I don't know haha    True          10
# 5159                                                 :)    True           1
# 5160  I read a your profile but was a little confuse...    True          26
# 5161  Yeah, mostly :) sorry I'm out with a friend, c...   False          16
# 5162                                 My bad, of course!    True           4
# 5163  Ok, free for now. So yeah, born and raised in ...   False          31
# 5164  I'm from queens! Haha I got to school for fash...    True          26
# 5165  That's cool, and I passed that urban outfitter...   False          25
# 5166  I've worked a couple shows not done many shoot...    True          30
# 5167  Program to get a foundation in fashion and sta...    True          12
# 5168  Very cool. Are you thinking of working in the ...   False          20
# 5169  Yeah definitely I'm thinking of doing an inter...    True          16
# 5170  That's so cool! I'm wrapping up my first year ...   False          37
# 5171       Haha, that's what we all want you to believe   False           9
# 5172  Busy man! Architecture school, you must be ver...    True           9
# 5173                   Haha, where doy ou do to school?    True           7
# 5174  Columbia, the grad school of arch. It's been a...   False          27
# 5175  Oh columbia! I live on the uws actually. I rea...    True          30
# 5176  I'll be around town til July, working on resea...   False          30
# 5177  That sounds so nice just up and leaving, are y...    True          21
# 5178  Haha, yes, should be back in august. And one's...   False          26
# 5179  You're very optimistic, I'm imagining that I w...    True          24
# 5180  Sleep is good, travel is good. Best thing: car...   False          23
# 5181  Definitely, either way I'm looking foward to h...    True          19
# ...                                                 ...     ...         ...
# 5592  I'm not being mean, mean would be ignoring you...    True          53
# 5593  Think back to when we started. I think we got ...   False          92
# 5594  Ok you're being dramatic now I have nothing el...    True          11
# 5595  This isn't an easy conversation to have. if yo...   False          35
# 5596  Hey, do you know about the Performa events goi...   False          26
# 5597  Last fall I met a guy. His eyes made my mind g...   False         574
# 5598  Im at work right now - I have no problem with ...    True          53
# 5599  You have been honest. I'd like to be friends t...   False          30
# 5600                                Thanks speak soon.     True           3
# 5601                                Hey, hows it going?   False           4
# 5602                              Hey just working you?    True           4
# 5603  Same, wrapping up my project for the final rev...   False          21
# 5604                           Hey Marcelo. How's life?   False           4
# 5605  Hey Aldo. Great just super busy with work and ...    True          14
# 5606         I'm good, just got back. Glad you're well.   False           8
# 5607  Hey, wanna catch up sometime? Maybe next weekend?   False           8
# 5608  Hey. Im pretty busy with fashion week prep sta...    True          28
# 5609  Go you! I've got a new guy too, so we're defin...   False          18
# 5610  Nice! Ya I'm chaperoning a party for natalies ...    True          26
# 5611                           Oh god. Yeah, talk soon.   False           5
# 5612                                         Okk night!    True           2
# 5613                                    Hey, hows life?   False           3
# 5614  The friend I was with when we met just moved b...   False          19
# 5615                                     Everything ok?   False           2
# 5616  I hope you're alive and well and are just igno...   False          32
# 5617  Out of all my friends, you run into the one wh...   False          21
# 5618     Let's get pizza tomorrow. It's been a while :)   False           9
# 5619  just want to see you again.  I do hope you dec...   False          16
# 5622                                             capton   False           1
# 5623                                                      False           0
#
#       positive  negative  neutral  compound
# 5152     0.000     0.000    1.000    0.0000
# 5153     0.474     0.000    0.526    0.8402
# 5154     0.211     0.291    0.498   -0.4753
# 5155     0.313     0.146    0.541    0.2714
# 5156     0.424     0.000    0.576    0.7964
# 5157     0.431     0.000    0.569    0.6486
# 5158     0.255     0.218    0.527    0.1078
# 5159     1.000     0.000    0.000    0.4588
# 5160     0.000     0.102    0.898   -0.3634
# 5161     0.491     0.059    0.450    0.8625
# 5162     0.000     0.558    0.442   -0.5848
# 5163     0.250     0.000    0.750    0.8102
# 5164     0.274     0.070    0.655    0.7604
# 5165     0.301     0.000    0.699    0.8426
# 5166     0.168     0.039    0.793    0.6213
# 5167     0.000     0.000    1.000    0.0000
# 5168     0.328     0.000    0.672    0.8070
# 5169     0.259     0.000    0.741    0.5994
# 5170     0.143     0.067    0.790    0.5069
# 5171     0.381     0.000    0.619    0.5106
# 5172     0.309     0.000    0.691    0.5540
# 5173     0.333     0.000    0.667    0.4588
# 5174     0.209     0.000    0.791    0.7476
# 5175     0.000     0.110    0.890   -0.4753
# 5176     0.103     0.000    0.897    0.4588
# 5177     0.162     0.091    0.747    0.4036
# 5178     0.340     0.000    0.660    0.8689
# 5179     0.237     0.000    0.763    0.7359
# 5180     0.406     0.000    0.594    0.9184
# 5181     0.137     0.000    0.863    0.4019
# ...        ...       ...      ...       ...
# 5592     0.098     0.120    0.782    0.2023
# 5593     0.250     0.085    0.665    0.9457
# 5594     0.196     0.000    0.804    0.2960
# 5595     0.254     0.134    0.612    0.7549
# 5596     0.000     0.000    1.000    0.0000
# 5597     0.154     0.112    0.734    0.9822
# 5598     0.157     0.155    0.688    0.4760
# 5599     0.413     0.000    0.587    0.9423
# 5600     0.592     0.000    0.408    0.4404
# 5601     0.000     0.000    1.000    0.0000
# 5602     0.000     0.000    1.000    0.0000
# 5603     0.000     0.000    1.000    0.0000
# 5604     0.000     0.000    1.000    0.0000
# 5605     0.502     0.000    0.498    0.9022
# 5606     0.615     0.000    0.385    0.7906
# 5607     0.000     0.000    1.000    0.0000
# 5608     0.260     0.000    0.740    0.8313
# 5609     0.313     0.000    0.687    0.7484
# 5610     0.155     0.000    0.845    0.4664
# 5611     0.589     0.000    0.411    0.5106
# 5612     0.000     0.000    1.000    0.0000
# 5613     0.000     0.000    1.000    0.0000
# 5614     0.158     0.000    0.842    0.4939
# 5615     0.688     0.000    0.313    0.2960
# 5616     0.441     0.064    0.495    0.9325
# 5617     0.310     0.000    0.690    0.7964
# 5618     0.300     0.000    0.700    0.4588
# 5619     0.244     0.000    0.756    0.4939
# 5622     0.000     0.000    1.000    0.0000
# 5623     0.000     0.000    0.000    0.0000
#
# [470 rows x 12 columns]

# %% [markdown]
# ## Cleaning all messages from both users and contacts
#
# ### Method
#
# - Read in the csv file
# - extract just the emails to play with
# - make a cleaning function
# - check what the cleaning function is doing

# %%
from nltk import tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import sys

sys.path.insert(0, '../mining')
import connector
import query
from vader_sentiment_analysis import SentimentAnalyser
import os
from bs4 import BeautifulSoup
import re

# %%
df = pd.read_csv("../data/SELECT_ALL_from_all_msgs_from_contacts_users.csv", 
                 header = 0)
df = df.drop(['Unnamed: 0'],axis=1)
# Out:
# 2016-08-15 12:56:45,233 | ERROR   | In #5 <-- ('127.0.0.1', 56328) to ('localhost', 5432) failed: SSHException('SSH session not active',)
# Traceback (most recent call last):
#   File "/home/sophie/anaconda3/envs/py27/lib/python2.7/SocketServer.py", line 596, in process_request_thread
#     self.finish_request(request, client_address)
#   File "/home/sophie/anaconda3/envs/py27/lib/python2.7/SocketServer.py", line 331, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/sophie/anaconda3/envs/py27/lib/python2.7/SocketServer.py", line 652, in __init__
#     self.handle()
#   File "/home/sophie/anaconda3/envs/py27/lib/python2.7/site-packages/sshtunnel.py", line 296, in handle
#     raise HandlerSSHTunnelForwarderError(msg)
# HandlerSSHTunnelForwarderError: In #5 <-- ('127.0.0.1', 56328) to ('localhost', 5432) failed: SSHException('SSH session not active',)
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 56328)
# ----------------------------------------

# %%
list(df)
# Out:
# ['user_id', 'contact_id', 'relationship', 'channel', 'sent_at', 'message']

# %%
df_emails = df[df['channel'] == 'gmail']

# %%
emails = df_emails['message'].tolist()

# %%
df_emails['user_id'].unique()[0:10]
# Out:
# array([  10.,   35.,   47.,   59.,   81.,   96.,   97.,  114.,  116.,  144.])

# %%
df_emails[['user_id','contact_id','relationship','message']][df_emails['user_id'] == 12284]
# Out:
#          user_id  contact_id relationship  \
# 2823142  12284.0     33098.0       Friend
# 2823152  12284.0     33098.0       Friend
# 2823153  12284.0     33098.0       Friend
# 2823166  12284.0     33098.0       Friend
# 2823167  12284.0     33098.0       Friend
# 2823168  12284.0     33098.0       Friend
# 2823189  12284.0     33098.0       Friend
# 2823193  12284.0     33098.0       Friend
# 2823194  12284.0     33098.0       Friend
# 2823204  12284.0     33098.0       Friend
# 2823205  12284.0     33098.0       Friend
# 2823206  12284.0     33098.0       Friend
# 2823207  12284.0     33098.0       Friend
# 2823208  12284.0     33098.0       Friend
# 2823209  12284.0     33098.0       Friend
# 2823210  12284.0     33098.0       Friend
# 2823211  12284.0     33098.0       Friend
# 2823212  12284.0     33098.0       Friend
# 2823213  12284.0     33098.0       Friend
# 2823214  12284.0     33098.0       Friend
# 2823215  12284.0     33098.0       Friend
# 2823216  12284.0     33098.0       Friend
# 2823217  12284.0     33098.0       Friend
# 2823218  12284.0     33098.0       Friend
# 2823219  12284.0     33098.0       Friend
# 2823220  12284.0     33098.0       Friend
# 2823221  12284.0     33098.0       Friend
# 2823222  12284.0     33098.0       Friend
# 2823223  12284.0     33098.0       Friend
# 2823224  12284.0     33098.0       Friend
# ...          ...         ...          ...
# 2824051  12284.0     33100.0       Friend
# 2824052  12284.0     33100.0       Friend
# 2824074  12284.0     33100.0       Friend
# 2824075  12284.0     33100.0       Friend
# 2824076  12284.0     33100.0       Friend
# 2824097  12284.0     33100.0       Friend
# 2824101  12284.0     33100.0       Friend
# 2824102  12284.0     33100.0       Friend
# 2824112  12284.0     33100.0       Friend
# 2824113  12284.0     33100.0       Friend
# 2824114  12284.0     33100.0       Friend
# 2824115  12284.0     33100.0       Friend
# 2824116  12284.0     33100.0       Friend
# 2824117  12284.0     33100.0       Friend
# 2824118  12284.0     33100.0       Friend
# 2824119  12284.0     33100.0       Friend
# 2824120  12284.0     33100.0       Friend
# 2824121  12284.0     33100.0       Friend
# 2824158  12284.0     33100.0       Friend
# 2824159  12284.0     33100.0       Friend
# 2824181  12284.0     33110.0      Partner
# 2824182  12284.0     33110.0      Partner
# 2824183  12284.0     33110.0      Partner
# 2824204  12284.0     33110.0      Partner
# 2824208  12284.0     33110.0      Partner
# 2824209  12284.0     33110.0      Partner
# 2824219  12284.0     33110.0      Partner
# 2824220  12284.0     33110.0      Partner
# 2824221  12284.0     33110.0      Partner
# 2824222  12284.0     33110.0      Partner
#
#                                                    message
# 2823142  Shit sorry completely forgot about this will s...
# 2823152  hmm let me know if its not there in the next f...
# 2823153                     Enjoy you got anything planned
# 2823166  Hi.\n\nI remember you mentioned how much you l...
# 2823167  Definitely Zabb Elee. Spicy food is my one tru...
# 2823168  I was hoping you’d say that.\n\nSee you then!\...
# 2823189  Here’s the link. I expect a full report back.\...
# 2823193          I’m 2 songs in and I love it already :)\n
# 2823194  Come over tonight and listen to the rest?\n\n-...
# 2823204  Sent from my iPhone\n\nBegin forwarded message...
# 2823205  https://www.techdirt.com/articles/20140609/072...
# 2823206  also, http://www.theguardian.com/environment/2...
# 2823207    http://www.businessinsider.com/cycorp-ai-2014-7
# 2823208  http://www.reddit.com/r/reddevils/comments/2dn...
# 2823209                              does it get you high?
# 2823210                                        interesting
# 2823211  Martin!!!\n\nLand Rover!!\n\nAre you sure you ...
# 2823212  Land Rover\n\nOpen in Docs\n\nGoogle Docs: Cre...
# 2823213  https://ssl.gstatic.com/docs/documents/share/i...
# 2823214  Chris White has invited you to edit the follow...
# 2823215  http://ssl.gstatic.com/docs/documents/share/im...
# 2823216     yeh just money to have fun - make somethink up
# 2823217  Might not be time before Sunday but of we get ...
# 2823218  have you seen the new sp?\n\nthis one is amazi...
# 2823219  http://www.damninteresting.com/on-the-origin-o...
# 2823220                  Nothing more than the fart of god
# 2823221                 http://voteforpolicies.org.uk/\n\n
# 2823222                     image001.jpg@01D03EEE.AF259A00
# 2823223  Chris White, MA (Oxon) MSc\n\nSenior Environme...
# 2823224  Haha great - martin were going to this tomorro...
# ...                                                    ...
# 2824051                                    YOU OWE ME ONE!
# 2824052  OMGZ how did it take her so long to get it?\n\...
# 2824074  Hi.\n\nI remember you mentioned how much you l...
# 2824075  Definitely Zabb Elee. Spicy food is my one tru...
# 2824076  I was hoping you’d say that.\n\nSee you then!\...
# 2824097  Here’s the link. I expect a full report back.\...
# 2824101          I’m 2 songs in and I love it already :)\n
# 2824102  Come over tonight and listen to the rest?\n\n-...
# 2824112                                           Ballad?!
# 2824113                                            tidal??
# 2824114     I'm just saying words that fit the letters...!
# 2824115                                            Come! x
# 2824116                                         Yayyyyyyyy
# 2824117  I am so excited! I wonder why fluffy didn't em...
# 2824118           are there tickets already? can not wait!
# 2824119  Wait look! http://www.residentadvisor.net/even...
# 2824120  That may have been premature, looks like I hav...
# 2824121                      How can you go on without me?
# 2824158                            Look at your hard work!
# 2824159                                        two graphs!
# 2824181  Hi.\n\nI remember you mentioned how much you l...
# 2824182  Definitely Zabb Elee. Spicy food is my one tru...
# 2824183  I was hoping you’d say that.\n\nSee you then!\...
# 2824204  Here’s the link. I expect a full report back.\...
# 2824208          I’m 2 songs in and I love it already :)\n
# 2824209  Come over tonight and listen to the rest?\n\n-...
# 2824219  It says you should include interests and hobbi...
# 2824220  I still think you should somehow involve the c...
# 2824221  Also say things like you enjoyed teaching Engl...
# 2824222  Where are you? I've booked an apartment in Ams...
#
# [833 rows x 4 columns]

# %%
print df[['channel','message']][0:10]
print len(df)
# Out:
#   channel                                            message
# 0   gmail  hey aldo,\nit was nice to meet you the other d...
# 1   gmail  That sounds great! My only complication is a g...
# 2   gmail  Alright. It looks like I'll be going to this T...
# 3   gmail  Hey Aldo! Sorry for not getting back to you.. ...
# 4   gmail  Hey Aldo!\nSorry for the slow reply; I'd defin...
# 5   gmail  Hey Aldo! Thanks so much for thinking of me an...
# 6   gmail  Hey Aldo!\nNo problem re: disappearing. I've b...
# 7   gmail  you could've just e-mailed w/ an emoticon\n;)\...
# 8   gmail  hey aldo,\nhere is the link for the movie i wa...
# 9   gmail  feeling *mostly* alright :)\ndefinitely didn't...
# 2867448

# %%
sql_query = """SELECT DISTINCT contacts.user_id AS user_id,
feed_items.from_id AS contact_id, contact_types.name AS relationship, channels.name
AS channel, feed_items.send_at AS sent_at, feed_items.body AS message
FROM feed_items
JOIN channels
ON feed_items.channel_id = channels.id
JOIN contacts
ON feed_items.from_id = contacts.id
JOIN contact_types
ON contacts.contact_type_id = contact_types.id
JOIN users
ON contacts.user_id = users.id
WHERE contacts.is_fake = false
UNION
SELECT DISTINCT contacts.user_id AS user_id,
feed_items.from_id AS contact_id, contact_types.name AS relationship, 
channels.name
AS channel, feed_items.send_at AS sent_at, feed_items.body AS message
FROM feed_items
JOIN channels ON feed_items.channel_id = channels.id
JOIN feeds ON feeds.id = feed_items.feed_id
JOIN contacts ON contacts.user_id = feeds.contact_id
JOIN contact_types ON contacts.contact_type_id = contact_types.id
JOIN users ON contacts.user_id = users.id
WHERE contacts.is_fake = false
ORDER BY user_id, contact_id, sent_at"""

dbconnection = connector.ConnectDB()
conn = dbconnection.get_connection()
q = query.Query(conn, sql_query)
query_list = q.get_query_list()
query_df = q.get_query_dataframe()
#q.write_df_to_csv()
query_df.shape
# Out:
# (2763818, 6)

# %%
#df_emails2 = query_df[query_df['channel'] == 'gmail']
#df_emails2[['user_id','contact_id','relationship','message','sent_at']][df_emails2['user_id'] == 12284][0:5]

# %%
# find occurrences of forwarded message
# Print out lines that contain \"Jerk\" and \"Mean\" to look for reasons why I may have dumped them

print df_emails[df_emails.message.str.contains('Begin Forwarded Message')][0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-312ccbf6c23b> in <module>()
#       2 # Print out lines that contain \"Jerk\" and \"Mean\" to look for reasons why I may have dumped them
#       3
# ----> 4 print df_emails[df_emails.message.str.contains('Begin Forwarded Message')][0:5]
#
# NameError: name 'df_emails' is not defined

# %%
df = pd.read_csv("../data/SELECT_ALL_from_all_msgs_from_contacts_users.csv", 
                 header = 0)

# %%
import pickle
import pandas as pd
from collections import Counter

# %%
pet_names_list = pd.read_csv('./pet_names.txt',sep='\n', header=-1)

# %%
pet_names_list = pet_names_list[0].str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-d2004fe77afb> in <module>()
# ----> 1 pet_names_list = pet_names_list[0].str.lower()
#
# /home/alexander/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /home/alexander/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1801
#    1802         # get column
# -> 1803         if self.columns.is_unique:
#    1804             return self._get_item_cache(key)
#    1805
#
# AttributeError: 'list' object has no attribute 'is_unique'

# %%
pet_names_list.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/alexander/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     668                 type_pprinters=self.type_printers,
#     669                 deferred_pprinters=self.deferred_printers)
# --> 670             printer.pretty(obj)
#     671             printer.flush()
#     672             return stream.getvalue()
#
# /home/alexander/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /home/alexander/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
# ...

# %%
all_messages = pd.read_pickle('./all_messages_to_from_pickled')

# %%
all_messages.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/alexander/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     668                 type_pprinters=self.type_printers,
#     669                 deferred_pprinters=self.deferred_printers)
# --> 670             printer.pretty(obj)
#     671             printer.flush()
#     672             return stream.getvalue()
#
# /home/alexander/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /home/alexander/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
# ...

# %%
c = Counter(pet_names_list)

# %%
message = 'hello Snookums Soul Mate Spark Sparkles'

# %%
c[x for x in message]
# Out:
#   File "<ipython-input-32-3d47c0b926d5>", line 1
#     c[x for x in message]
#           ^
# SyntaxError: invalid syntax

# %%
for pet_name in pet_names_list:
    pet_name_count = all_messages.message.str.contains(pet_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-4fa6529889a3> in <module>()
#       1 for pet_name in pet_names_list:
# ----> 2     pet_name_count = all_messages.message.str.contains(pet_name)
#
# /home/alexander/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'message'
